# %% [markdown]
# ## Observations and Insights

# %% [markdown]
# ## Dependencies and starter code

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import scipy.stats as st

# Study data files
mouse_metadata = "Mouse_metadata.csv"
study_results = "Study_results.csv"

# Read the mouse data and the study results
mouse_metadata = pd.read_csv(mouse_metadata)
#print(mouse_metadata)
study_results = pd.read_csv(study_results)
#print(study_results)

# Combine the data into a single dataset
data_df = pd.merge(mouse_metadata, study_results, on = ["Mouse ID", "Mouse ID"])
data_df.head()
# Out:
#   Mouse ID Drug Regimen   Sex  Age_months  Weight (g)  Timepoint  \
# 0     k403     Ramicane  Male          21          16          0
# 1     k403     Ramicane  Male          21          16          5
# 2     k403     Ramicane  Male          21          16         10
# 3     k403     Ramicane  Male          21          16         15
# 4     k403     Ramicane  Male          21          16         20
#
#    Tumor Volume (mm3)  Metastatic Sites
# 0           45.000000                 0
# 1           38.825898                 0
# 2           35.014271                 1
# 3           34.223992                 1
# 4           32.997729                 1

# %% [markdown]
# ## Summary statistics

# %%
# Summary statistics table of mean, median, variance, standard deviation, and SEM of the tumor volume for each regimen
tv_mean = data_df["Tumor Volume (mm3)"].mean()
tv_median = data_df["Tumor Volume (mm3)"].median()
tv_var = data_df["Tumor Volume (mm3)"].var()
tv_std = data_df["Tumor Volume (mm3)"].std()
tv_sem  = st.sem(data_df["Tumor Volume (mm3)"])

# Create an index for the previous calculations
index = ["Mean", "Median", "Variance", "Standard Deviation", "SEM"]

# Create a DataFrame based on the previous index and calculaions
statistics_df = pd.DataFrame({"Tumor Volume (mm3)":[tv_mean, tv_median, tv_var, tv_std, tv_sem]}, index)

# Display the DataFrame
statistics_df.head()
# Out:
#                     Tumor Volume (mm3)
# Mean                         50.448381
# Median                       48.951474
# Variance                     79.116074
# Standard Deviation            8.894722
# SEM                           0.204436

# %% [markdown]
# ## Bar plots

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pandas
# Counts the number of data points for each regimen
treatments = data_df["Drug Regimen"].value_counts()

# Create a DataFrame based on the data points and add an index
treat_df = treatments.to_frame(name = "Data Points")
treat_df.index.name = "Drug Regimen"
#treat_df.head()

# Pandas bar-plot the DataFrame
treat_df.plot(kind = "bar", alpha = 0.5, legend = None, figsize = (10, 7))

# Add title and y-axis label (the x-axis comes from the index name)
plt.title("Drug Regimen Data Points")
plt.ylabel("Data Points")

# Rotate the x-axis names to 45 degrees
plt.xticks(rotation = 45)

# Add margins
plt.xlim(-1, len(treat_df.index))
plt.ylim(0, max(treat_df["Data Points"]) + 25)

# Display the plot with a tight layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Generate a bar plot showing number of data points for each treatment regimen using pyplot
# Create a list with the x-axis values
x_ax = list(treat_df.index)

# Create a figure to plot on, set the figure size
fig1, ax1 = plt.subplots(figsize = (10, 7))

# Pyplot the DataFrame as bar plot
plt.bar(x_ax, treat_df["Data Points"], align = "center", color = "red", alpha = 0.5)

# Add title
plt.title("Drug Regimen Data Points")
plt.xlabel("Drug Regimen")
plt.ylabel("Data Points")

# Rotate the x-axis names to 45 degrees
plt.xticks(rotation = 45)

# Add margins
plt.xlim(-1, len(x_ax))
plt.ylim(0, max(treat_df["Data Points"]) + 25)

# Display the plot with a tight layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Pie plots

# %%
# Generate a pie plot showing the distribution of female versus male mice using pandas
# Count the values for male and female
genders = data_df["Sex"].value_counts()

# Create a DataFrame with the gender information
gender_df = genders.to_frame(name = "Count")

# Add an index
gender_df.index.name = "Gender"
#gender_df.head()

# Pandas pie-plot the DataFrame
gender_df["Count"].plot(kind = "pie", figsize = (7,7), explode = (0.05, 0), shadow=True, startangle=180, autopct="%1.2f%%")

# Add title and remove y-label
plt.title("Mice Gender Distribution")
plt.ylabel(" ")

# Display the plot with a tight layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Generate a pie plot showing the distribution of female versus male mice using pyplot
# Create a list with genders
gender = list(gender_df.index)
#print(gender)

# Create a figure to plot on, set its size
fig3, ax3 = plt.subplots(figsize = (9, 9))

# Add a separation between pie fragments
explode = (0.05, 0)

# Pyplot the DataFrame
plt.pie(gender_df["Count"], explode, gender, colors = ("teal", "lightcoral"), autopct="%1.2f%%", shadow = True, startangle = -115)

# Add title
plt.title("Mice Gender Distribution")

# Show the plot
plt.show()

# %% [markdown]
# ## Quartiles, outliers and boxplots

# %%
# Calculate the final tumor volume of each mouse across four of the most promising treatment regimens.
# Calculate the IQR and quantitatively determine if there are any potential outliers. 

# Sort the DataFrame values by mouse ID from largest to smallest timepoint (last to first), store in new DFs
last_point_df = data_df.groupby(["Mouse ID"]).max().reset_index()[["Mouse ID","Timepoint"]]
last_tumor_df = last_point_df.merge(data_df, on=["Mouse ID","Timepoint"], how = "left")

#last_tumor_df = last_tumor_df.sort_values(by = "Tumor Volume (mm3)", ascending = True)
#last_tumor_df.head()

# Sort the DataFrame by drug regimen and gather the smallest tumor volume, store into a new DF
best_treat_df = last_tumor_df.groupby(["Drug Regimen"])[["Tumor Volume (mm3)"]].min().reset_index()


#best_treat_df = best_treat_df.sort_values(by = "Tumor Volume (mm3)", ascending = True)
#best_treat_df.head()

# Create a new DataFrame gathering only the four drug regimens listed
bt = last_tumor_df["Drug Regimen"].isin(["Ramicane", "Capomulin", "Infubinol", "Ceftamin"])
bt_df = last_tumor_df[bt]
#bt_df.head()

# Calculate quartiles
tv_quartiles = bt_df["Tumor Volume (mm3)"].quantile([0.25, 0.75])
tv_lowq = tv_quartiles[0.25]
tv_upq = tv_quartiles[0.75]
#print(tv_lowq)
#print(tv_upq)

# Calculate interquartile range
iqr = tv_upq - tv_lowq
#print(iqr)

# Calculate outlier boundaries
l_bound = tv_lowq - (1.5*iqr)
u_bound = tv_upq + (1.5*iqr)

# Print the possible outlier boundaries
print(f'The values below {l_bound} could be outliers')
print(f'The values above {u_bound} could be outliers')
# Out:
# The values below 3.0739668737499812 could be outliers
# The values above 94.04403868375002 could be outliers

# %%
# Generate a box plot of the final tumor volume of each mouse across four regimens of interest
# Set the type of data to make easier to use
tumor_vol = bt_df["Tumor Volume (mm3)"].astype(int)
#print(tumor_vol)

# Create a DF for each drug regimen
rami_df = last_tumor_df[last_tumor_df["Drug Regimen"] == "Ramicane"]["Tumor Volume (mm3)"]
capo_df = last_tumor_df[last_tumor_df["Drug Regimen"] == "Capomulin"]["Tumor Volume (mm3)"]
infu_df = last_tumor_df[last_tumor_df["Drug Regimen"] == "Infubinol"]["Tumor Volume (mm3)"]
cefta_df = last_tumor_df[last_tumor_df["Drug Regimen"] == "Ceftamin"]["Tumor Volume (mm3)"]

# Create a new figure to plot on
fig4, ax4 = plt.subplots(figsize = (12,8))

# Set title and y-axis label (x-axis label is retrieved from DF index)
ax4.set_title("Mice Tumor Volume per Regimen")
ax4.set_ylabel("Tumor Volume (mm3)")

# Give format to outlier
blue_diamond = dict(markerfacecolor='b', marker='D')

# Label each DF plot
labels = ["Ramicane", "Capomulin", "Infubinol", "Ceftamin"]

# Boxplot
ax4.boxplot([rami_df, capo_df, infu_df, cefta_df], flierprops=blue_diamond, labels = labels)

# Display the plot with a tight layout
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# ## Line and scatter plots

# %%
# Generate a line plot of time point versus tumor volume for a mouse treated with Capomulin
# Select the mice treated with Capomulin
capo_mouse_df = data_df.loc[data_df["Drug Regimen"] == "Capomulin"]

# Select one mouse from all the mice treated with Capomulin
capo_mouseid_df = capo_mouse_df.loc[data_df["Mouse ID"] == "s185"]
#capo_mouseid_df.head()

# Pandas line-plot the timepoint vs tumor volume relation
capo_mouseid_df.plot.line(x = "Timepoint", y = "Tumor Volume (mm3)", legend = False, color = "pink", marker = "^", figsize = (10,7))

# Add title and y-label (x-label is retrieved from the DF index)
plt.title("Tumor Volume in Time for s185 Mouse (Capomulin regimen)")
plt.ylabel("Tumor Volume (mm3)")

# Display the plot in a tight layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Generate a scatter plot of mouse weight versus average tumor volume for the Capomulin regimen
# Calculate the mean tumor volume per mouse
tumor = capo_mouse_df.groupby(["Mouse ID"])["Tumor Volume (mm3)"].mean()
#print(len(tumor))

# Select only the data regarding the Capomulin regimen
useful = mouse_metadata.loc[mouse_metadata["Drug Regimen"] == "Capomulin"].sort_values(by='Mouse ID')

# Store the weight
weight = useful["Weight (g)"]
#print(len(weight))

# Create a figure to plot on, set its size
fig5, ax5 = plt.subplots(figsize = (10, 7))

# Pyplot the weight-tumor volume in a scatter plot
plt.scatter(weight, tumor)

# Add title and labels
plt.title("Mouse Weight vs Average Tumor Volume")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")

# Display the plot in a tight layout
plt.tight_layout()

# Show the plot
plt.show()

# %%
# Calculate the correlation coefficient and linear regression model for mouse weight and average tumor volume for the Capomulin regimen
correlation = st.pearsonr(weight, tumor)

# Print the correlation coefficient
print(f'The correlation between each mouse weight and average tumor volume is {round(correlation[0], 2)}')

# Linear regression function, taking in as arguments the x and y lists, and returning the slope, the intercept
# the r-value, p-value and the stderr
(slope, intercept, rvalue, pvalue, stderr) = st.linregress(weight, tumor)

# Linear regression values, multiplying the x list value by the slope and adding the intercept
regress_values = weight*slope+intercept

# Line equation expressed as y = mx + b, where m is the slope and b is the intercept
line_eq = "y = " + str(round(slope, 2)) + "x + " + str(round(intercept, 2)) 

# Create a figure to plot on, set its size
fig6, ax6 = plt.subplots(figsize = (10, 7))

# Pyplot the weight-tumor volume scatter plot
plt.scatter(weight, tumor)

# Plot the regression line and annotate its function in the (20, 38) interception
plt.plot(weight, regress_values, "r-")
plt.annotate(line_eq, (20, 38), fontsize = 15, color = "red")

# Add title and labels
plt.title("Mouse Weiight vs Average Tumor Volume")
plt.xlabel("Mouse Weight (g)")
plt.ylabel("Average Tumor Volume (mm3)")

# Display the plot in a tight layout
plt.tight_layout()

# Show the plot
plt.show()
# Out:
# The correlation between each mouse weight and average tumor volume is 0.84

# %% [markdown]
# ## Insight Values
#
# * The Ramicane and Capomulin are the drug regimens with the most Datapoints.
#
# * Most mice treated with Capomulin and Ramicane had a notorious decrease in the Average Tumor Volume.
#
# * The mice gender was almost equally distributed between male and female.
#
# * The mean final Average Tumor Volume for the Ramicane treated mice was the smallest between the four most promising treatments.
#
# * The Ramicane IQR is larger than the Capomulin IQR
#
# * The heavier the mouse, the larger the tumor
